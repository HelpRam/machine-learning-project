# %%
# !pip install dtale
# Out:
# ...
#   Using cached dtale-3.1.0-py2.py3-none-any.whl (14.1 MB)
# ...
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# ...
#   Using cached Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# ...
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# ...
#   Using cached dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
# ...
#   Using cached dash-2.11.0-py3-none-any.whl (10.4 MB)
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\ramme\Downloads\Programs\Lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "C:\Users\ramme\Downloads\Programs\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ramme\Downloads\Programs\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
# ...

# %%
# !pip install dtale

# %%
import pandas as pd
import dtale

# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://RamDular:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2023-06-27 13:17:47,199 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,246 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,249 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,256 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,257 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,259 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,264 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,270 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-06-27 13:17:47,272 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
